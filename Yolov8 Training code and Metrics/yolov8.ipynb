# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 592.7/592.7 kB 8.0 MB/s eta 0:00:00
# ...

# %%
# !pip install clearml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.4 MB/s eta 0:00:00
# ...

# %%
# !clearml-init
# Out:
# ClearML SDK setup process
#
# Please create new clearml credentials through the settings page in your `clearml-server` web app (e.g. http://localhost:8080//settings/workspace-configuration)
# Or create a free account at https://app.clear.ml/settings/workspace-configuration
#
# In settings page, press "Create new credentials", then press "Copy to clipboard".
#
# Paste copied configuration here:
# api {      # Abhay Shastry's workspace     web_server: https://app.clear.ml     api_server: https://api.clear.ml     files_server: https://files.clear.ml     credentials {         "access_key" = "1S6CGGBJ7RS5BQNQ22KG"         "secret_key"  = "NRMGtRyiQS2ljPrFCsSNNcfhFVRIZ8yRJNYR8EYkVjKK6BqBml"     } }
# Detected credentials key="1S6CGGBJ7RS5BQNQ22KG" secret="NRMG***"
#
# ClearML Hosts configuration:
# Web App: https://app.clear.ml
# API: https://api.clear.ml
# File Store: https://files.clear.ml
#
# Verifying credentials ...
# Credentials verified!
#
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="7i5OC3BYUuBu5ohFyuZS")
project = rf.workspace("abhay-shastry-is3gb").project("crack-0gcp0")
dataset = project.version(3).download("yolov8")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.9 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9657 sha256=6a5eb2dde20f8293696a70ef8e33df267bb38ee435c7ca4259b18fa0f46eec26
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
# ...

# %%
# !yolo task=detect mode=train model=yolov8l.pt imgsz=640 data='/content/crack-3/data.yaml' epochs=100 batch=8 name=model_road_crack2
# Out:
# Ultralytics YOLOv8.0.110 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cp '/content/runs/detect/model_road_crack24' -r '/content/drive/MyDrive/Crack Detection'

# %%
# !yolo task=detect mode=val model='/content/drive/MyDrive/Crack Detection/model_road_crack24/weights/best.pt' name=yolov8m_eval data='/content/crack-2/data.yaml' imgsz=480
# Out:
# Ultralytics YOLOv8.0.109 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43607379 parameters, 0 gradients
# val: Scanning /content/crack-2/valid/labels.cache... 76 images, 0 backgrounds, 0 corrupt: 100% 76/76 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5/5 [00:03<00:00,  1.35it/s]
#                    all         76         85      0.835      0.824      0.885       0.61
# Speed: 2.2ms preprocess, 21.7ms inference, 0.0ms loss, 3.6ms postprocess per image
# Results saved to runs/detect/yolov8m_eval

# %%
# !yolo task=detect mode=predict model='/content/drive/MyDrive/Crack Detection/model_road_crack24/weights/best.pt' source='/content/drive/MyDrive/Crack Detection/No copyright City Background Video Free Stock Footage Rainy Street.mp4' show=True imgsz=1240 name=yolo1_infer
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.0.110 🚀 Python-3.10.11 torch-2.0.1+cu118 CPU
# Model summary (fused): 268 layers, 43607379 parameters, 0 gradients
#
# WARNING ⚠️ imgsz=[1240] must be multiple of max stride 32, updating to [1248]
# video 1/1 (1/2700) /content/drive/MyDrive/Crack Detection/No copyright City Background Video Free Stock Footage Rainy Street.mp4: 704x1248 11 cracks, 5955.1ms
# video 1/1 (2/2700) /content/drive/MyDrive/Crack Detection/No copyright City Background Video Free Stock Footage Rainy Street.mp4: 704x1248 11 cracks, 5981.1ms
# video 1/1 (3/2700) /content/drive/MyDrive/Crack Detection/No copyright City Background Video Free Stock Footage Rainy Street.mp4: 704x1248 11 cracks, 8982.0ms
# video 1/1 (4/2700) /content/drive/MyDrive/Crack Detection/No copyright City Background Video Free Stock Footage Rainy Street.mp4: 704x1248 11 cracks, 5675.4ms
# ...

# %%
model = YOLO("yolov8s.pt")
results = model.predict(source="https://ultralytics.com/images/bus.jpg")[0]

model.export(format="onnx",opset=12)
